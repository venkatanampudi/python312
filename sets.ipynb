# %% [markdown]
# # Sets
# * Sets are **unordered** collection of __unique__ elements. Meaning there can only be one representative of the same object

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
# lets add 2 again 
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
#CONVERTING LIST INTO SET
mylist=[1,2,3,1,2,9,0,2,2]
set(mylist)
# Out:
# {0, 1, 2, 3, 9}

# %%
# Write an expression that would turn the string 'Mississippi' into a seq of unique letters.
set('Mississippi')
# Out:
# {'M', 'i', 'p', 's'}
