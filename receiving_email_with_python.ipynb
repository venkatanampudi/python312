# %% [markdown]
# ### VIEWING EMAIL WITH PYTHON
# - To view received emails with Python we can use the built in __imaplib__ and email libraries in Python
# - The imaplib library has a special syntax for searching your inbox

# %%
import imaplib

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
email = getpass.getpass("Email: ")
password = getpass.getpass("Password: ")
# Out:
# Email:  ········
# Password:  ········

# %%
M.login(email,password)
# Out:
# ('OK', [b'venkat.anampudi@gmail.com authenticated (Success)'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "Aspire"',
#   b'(\\HasNoChildren) "/" "Coursera"',
#   b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasNoChildren) "/" "Illinois Tech"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasChildren \\Trash) "/" "[Gmail]/Trash"',
#   b'(\\HasNoChildren) "/" "[Gmail]/Trash/Creative Ceramic Tile"',
#   b'(\\HasNoChildren) "/" "[Gmail]/Trash/Roman Landscaping LLC"',
#   b'(\\HasNoChildren) "/" "[Gmail]/Trash/Safe Life Security(Avi)"',
#   b'(\\HasNoChildren) "/" "[Gmail]/Trash/SkillSpeed"',
#   b'(\\HasNoChildren) "/" "[Gmail]/Trash/USPS"'])

# %%
M.select('inbox')
# Out:
# ('OK', [b'78439'])

# %%
typ, data = M.search(None,'SUBJECT "Python312"')

# %%
typ
# Out:
# 'OK'

# %%
data
# Out:
# [b'78436']

# %%
email_id = data [0]

# %%
result, email_data = M.fetch(email_id, '(RFC822)')
# Out:
# ---------------------------------------------------------------------------
# abort                                     Traceback (most recent call last)
# File ~\anaconda3\Lib\imaplib.py:1056, in IMAP4._command_complete(self, name, tag)
#    1055 try:
# -> 1056     typ, data = self._get_tagged_response(tag, expect_bye=logout)
#    1057 except self.abort as val:
#
# File ~\anaconda3\Lib\imaplib.py:1182, in IMAP4._get_tagged_response(self, tag, expect_bye)
#    1181 try:
# -> 1182     self._get_response()
#    1183 except self.abort as val:
#
# File ~\anaconda3\Lib\imaplib.py:1084, in IMAP4._get_response(self)
#    1077 def _get_response(self):
#    1078
#    1079     # Read response and store.
#    1080     #
#    1081     # Returns None for continuation responses,
#    1082     # otherwise first response line received.
# -> 1084     resp = self._get_line()
#    1086     # Command completion response?
#
# File ~\anaconda3\Lib\imaplib.py:1194, in IMAP4._get_line(self)
# ...

# %%
raw_email = email_data[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 raw_email = email_data[0][1]
#
# NameError: name 'email_data' is not defined

# %%
raw_email_string = raw_email.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 raw_email_string = raw_email.decode('utf-8')
#
# NameError: name 'raw_email' is not defined

# %%
import email

# %%
email_message = email.message_from_string(raw_email_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 email_message = email.message_from_string(raw_email_string)
#
# NameError: name 'raw_email_string' is not defined

# %%
for part in email_message.walk():
    if part.get_content_type() == 'text/plain':
        body = part.get_payload(decode=True)
        print(body)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for part in email_message.walk():
#       2     if part.get_content_type() == 'text/plain':
#       3         body = part.get_payload(decode=True)
#
# NameError: name 'email_message' is not defined
