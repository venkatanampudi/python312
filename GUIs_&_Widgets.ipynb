# %% [markdown]
# ### Introduction to GUIs

# %%
pip install -U ipywidgets
# Out:
# ...
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.7
#     Uninstalling ipywidgets-8.1.7:
#       Successfully uninstalled ipywidgets-8.1.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ipywidgets import interact,interactive,fixed
import ipywidgets as widgets

# %%
def func(x):
    return x

# %%
interact(func,x=10)

# %%
def func(y):
    return y**2

# %%
interact(func,y=10)

# %%
interact(func,x=True)

# %%
def func(x):
    return x

# %%
interact(func,x=True)

# %%
interact(func,x=False)

# %%
interact(func,x='Hello')

# %%
@interact(x=True,y=1.0)
def g(x,y):
    return (x,y)

# %%
@interact(x=True,y=fixed(1.0)) # with fixed value for y
def g(x,y):
    return (x,y)

# %%
interact(func,x=1) # min is x, max is x*3

# %%
interact(func,x=10) # min is x, max is x*3

# %%
interact(func,x=widgets.IntSlider(min=-100,max=100,step=1,value=0))

# %%
interact(func,x=widgets.IntSlider(min=-100,max=100,step=5,value=0))

# %%
# ABBREVIATE THE SAME ABOVE FUNCTIONALITY HERE (-100,100,1) - this is abbreviation format). Passing a tuple instead of Integer Slider (IntSlider).
interact(func,x=(-100,100,1))

# %%
# THIS IS FLOATSLIDER
interact(func,x=(-10.0,10.0,.1))

# %%
@interact(x=(0.0,20.0,0.5))
def h(x=5.0):
    return x

# %%
interact(func,x=['option1','option2','option3'])

# %%
interact(func,x={'one':1,'two':2,'three':3}) # value not changing according to drop down selection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 interact(func,x={'one':1,'two':2,'three':3})
#
# NameError: name 'interact' is not defined

# %%
jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[2], line 1
#     jupyter nbextension enable --py widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
from ipywidgets import interact

def func(x):
    print(f"You selected: {x}")

interact(func, x={'one':1,'two':2,'three':3})
# Out:
# interactive(children=(Dropdown(description='x', options={'one': 1, 'two': 2, 'three': 3}, value=1), Output()),…
# <function __main__.func(x)>

# %%
# %pip install --upgrade ipywidgets

# %%
from ipywidgets import interact,interactive,fixed
import ipywidgets as widgets

from IPython.display import display 

def f(a,b):
    display(a+b)
    return a+b

# %%
w = interactive(f,a=10,b=20)

# %%
type(w)
# Out:
# ipywidgets.widgets.interaction.interactive

# %%
w.children
# Out:
# (IntSlider(value=10, description='a', max=30, min=-10),
#  IntSlider(value=20, description='b', max=60, min=-20),
#  Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': '30'}, 'metadata': {}},)))

# %%
display(w) # the value not chaing accroding to slider.
# Out:
# interactive(children=(IntSlider(value=10, description='a', max=30, min=-10), IntSlider(value=20, description='…

# %% [markdown]
# ### Widget Basics

# %%
import ipywidgets as widgets

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
w = widgets.IntSlider()

# %%
from IPython.display import display

# %%
display(w)
# Out:
# IntSlider(value=0)

# %%
display(w)
# Out:
# IntSlider(value=0)

# %%
# Above both sliders are in sync. If you slider one, other slider also moves because they both refer same widget object

# %%
w.close() # TO CLOSE THE WIDGET

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.value # FOR THE CURRENT SLIDER VALUE
# Out:
# 0

# %%
w.value = 27 # TO UPDATE THE VALUE

# %%
w.keys # stateful properties of widgets
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'behavior',
#  'continuous_update',
#  'description',
#  'description_allow_html',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'tabbable',
#  'tooltip',
#  'value']

# %%
w.max = 2000

# %%
# THESE BOTH WIDGETS NOT CONNECTED
a = widgets.FloatText()
b = widgets.FloatSlider()
display(a,b)
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
display(a)
# Out:
# FloatText(value=0.0)

# %%
# THESE BOTH WIDGETS ARE CONNECTED with jslink
a = widgets.FloatText()
b = widgets.FloatSlider()

display(a,b)

mylink = widgets.jslink((a,'value'),(b,'value'))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
# THESE BOTH WIDGETS ARE CONNECTED with jslink and b with max value. Enter 1000 in slider, so slider also goes until 1000
a = widgets.FloatText()
b = widgets.FloatSlider()

display(a,b)

mylink = widgets.jslink((a,'value'),(b,'max'))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
# TO UNLINK BOTH WIDGETS
mylink.unlink()

# %% [markdown]
# ### Widget List
# - ```For a complete list of the GUI widgets available to you, you can list the registered widget types.```
# - ```"Widget" is the base class```

# %%
import ipywidgets as widgets

# Show all available widgets
for item in widgets.Widget.widget_types.items():
    print(item[0])
# Out:
# ('@jupyter-widgets/base', '2.0.0', 'LayoutModel', '@jupyter-widgets/base', '2.0.0', 'LayoutView')
# ('@jupyter-widgets/controls', '2.0.0', 'AccordionModel', '@jupyter-widgets/controls', '2.0.0', 'AccordionView')
# ('@jupyter-widgets/controls', '2.0.0', 'AudioModel', '@jupyter-widgets/controls', '2.0.0', 'AudioView')
# ('@jupyter-widgets/controls', '2.0.0', 'BoundedFloatTextModel', '@jupyter-widgets/controls', '2.0.0', 'FloatTextView')
# ('@jupyter-widgets/controls', '2.0.0', 'BoundedIntTextModel', '@jupyter-widgets/controls', '2.0.0', 'IntTextView')
# ('@jupyter-widgets/controls', '2.0.0', 'BoxModel', '@jupyter-widgets/controls', '2.0.0', 'BoxView')
# ('@jupyter-widgets/controls', '2.0.0', 'ButtonModel', '@jupyter-widgets/controls', '2.0.0', 'ButtonView')
# ('@jupyter-widgets/controls', '2.0.0', 'ButtonStyleModel', '@jupyter-widgets/base', '2.0.0', 'StyleView')
# ('@jupyter-widgets/controls', '2.0.0', 'CheckboxModel', '@jupyter-widgets/controls', '2.0.0', 'CheckboxView')
# ...

# %% [markdown]
# ### Numeric Widgets
# ##### There are 10 widgets distributed with IPython that are designed to display numeric values. Widgets exist for displaying integers and floats, bounded and unbounded. The integer widgets share a similar naming scheme to their floating point counterparts. By replacing Float with Int in the widget name, you can find the Integer equavalent.

# %% [markdown]
# ### IntSlider

# %%
widgets.IntSlider(
    value=7,
    min=0,
    max=100,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
# Out:
# IntSlider(value=7, continuous_update=False, description='Test:')

# %%
widgets.FloatSlider(
    value=2.0,
    min=0,
    max=100.0,
    step=0.5,
    description='FloatSlider:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f'
)
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='FloatSlider:', readout_format='.1f', step=0.5)

# %% [markdown]
# ### FloatSlider

# %%
# DISPLAYED VERTICALLY
widgets.FloatSlider(
    value=2.0,
    min=0,
    max=100.0,
    step=0.5,
    description='FloatSlider:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
    readout_format='.1f'
)
# Out:
# FloatSlider(value=2.0, continuous_update=False, description='FloatSlider:', orientation='vertical', readout_fo…

# %% [markdown]
# ### IntRangeSlider

# %%
widgets.IntRangeSlider(
    value=[5,7],
    min=0,
    max=100.0,
    step=0.5,
    description='FloatSlider:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
    readout_format='d'
)
# Out:
# IntRangeSlider(value=(5, 7), continuous_update=False, description='FloatSlider:', orientation='vertical', step…

# %% [markdown]
# ### FloatRangeSlider

# %%
widgets.IntRangeSlider(
    value=[5,7.5],
    min=0,
    max=100.0,
    step=0.5,
    description='FloatSlider:',
    disabled=False,
    continuous_update=False,
    orientation='vertical',
    readout=True,
    readout_format='.1f'
)
# Out:
# IntRangeSlider(value=(5, 7), continuous_update=False, description='FloatSlider:', orientation='vertical', read…

# %% [markdown]
# ### IntProgress

# %%
widgets.IntProgress(
    value=7,
    min=0,
    max=10.0,
    step=1,
    description='Loading:',
    bar_style='', # 'success', 'info', 'warning', 'danger', or ''
    orientation='horizontal'
)
# Out:
# IntProgress(value=7, description='Loading:', max=10)

# %%
widgets.FloatProgress(
    value=7.5,
    min=0,
    max=10.0,
    step=.5,
    description='Loading:',
    bar_style='danger', #'info', 'warning', 'danger', or ''
    orientation='horizontal'
)
# Out:
# FloatProgress(value=7.5, bar_style='danger', description='Loading:', max=10.0)

# %% [markdown]
# ### BoundedIntText

# %%
widgets.BoundedIntText(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Text:',
    disabled=False
)
# Out:
# BoundedIntText(value=7, description='Text:', max=10)

# %% [markdown]
# ### BoundedFloatText

# %%
widgets.BoundedFloatText(
    value=5.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Text:',
    disabled=False
)
# Out:
# BoundedFloatText(value=5.5, description='Text:', max=10.0, step=0.1)

# %% [markdown]
# ### IntText

# %%
widgets.IntText(
    value=7,
    description='Any:',
    disabled=False
)
# Out:
# IntText(value=7, description='Any:')

# %% [markdown]
# # Boolean Widgets

# %% [markdown]
# ### ToggleButton

# %%
widgets.ToggleButton(
    value=False,
    description='Click me:',
    disabled=False,
    button_style='success',  # 'success', 'warning', 'info','danger' or ''
    tooltip='Description',
    icon='check'
)
# Out:
# ToggleButton(value=False, button_style='success', description='Click me:', icon='check', tooltip='Description'…

# %% [markdown]
# ### Checkbox

# %%
widgets.Checkbox(
    value=False,
    description='Click me:',
    disabled=False
)
# Out:
# Checkbox(value=False, description='Click me:')

# %% [markdown]
# ### Valid

# %%
widgets.Valid(
    value=False,
    description='Valid!'
)
# Out:
# Valid(value=False, description='Valid!')

# %%
widgets.Valid(
    value=True,
    description='Valid!'
)
# Out:
# Valid(value=True, description='Valid!')

# %% [markdown]
# ### Dropdown

# %%
widgets.Dropdown(
    options=['1','2','3'],
    value='1',
    description='Number:',
    disabled=False
)
# Out:
# Dropdown(description='Number:', options=('1', '2', '3'), value='1')

# %%
widgets.Dropdown(
    options={'One':1,'Two':2,'Three':3},
    value=2,
    description='Number:'
)
# Out:
# Dropdown(description='Number:', index=1, options={'One': 1, 'Two': 2, 'Three': 3}, value=2)

# %% [markdown]
# ### RadioButtons

# %%
widgets.RadioButtons(
    options=['Apples','Oranges','Blueberries'],
    #value=2,
    description='Fruit Selection:',
    disabled=False
)
# Out:
# RadioButtons(description='Fruit Selection:', options=('Apples', 'Oranges', 'Blueberries'), value='Apples')

# %% [markdown]
# ### Select

# %%
widgets.Select(
    options=['Linux','Windows','MacOS'],
    value='MacOS',
    description='OS:',
    disabled=False
)
# Out:
# Select(description='OS:', index=2, options=('Linux', 'Windows', 'MacOS'), value='MacOS')

# %% [markdown]
# ### SelectionSlider

# %%
widgets.SelectionSlider(
    options=['scrambled','sunny side up','poached','over easy'],
    value='sunny side up',
    description='I like my eggs...',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    reaout=True
)
# Out:
# SelectionSlider(continuous_update=False, description='I like my eggs...', index=1, options=('scrambled', 'sunn…

# %% [markdown]
# ### SelectionRangeSlider

# %% [markdown]
# ### ToggleButtons

# %%
import ipywidgets as widgets

widgets.ToggleButtons(
    options=['Slow','Regular','Fast'],
    description='Speed:',
    disabled=False,
    button_style='',  # 'success', 'warning', 'info','danger' or ''
    tooltips=['Description of slow','Description of regular','Description of fast'],
    #icon='check'
)
# Out:
# ToggleButtons(description='Speed:', options=('Slow', 'Regular', 'Fast'), tooltips=('Description of slow', 'Des…

# %% [markdown]
# ### SelectMultiple

# %%
widgets.SelectMultiple(
    options=['Apples','Oranges','Pears'],
    value=['Oranges'],
    description='Fruits',
    disabled=False
)
# Out:
# SelectMultiple(description='Fruits', index=(1,), options=('Apples', 'Oranges', 'Pears'), value=('Oranges',))

# %% [markdown]
# # String widgets
# #### There are several widgets that can be used to display a string value. The Text and Textarea widgets accept input. The HTML and HTMLMath widgets display a string as HTML (HTMLMath also renders math). The Label widget can be used to construct a custom control label

# %% [markdown]
# ### Text

# %%
widgets.Text(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)
# Out:
# Text(value='Hello World', description='String:', placeholder='Type something')

# %%
widgets.Textarea(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)
# Out:
# Textarea(value='Hello World', description='String:', placeholder='Type something')

# %%
widgets.HBox([widgets.Label(value="The  $m$  in $E=mc^2$:"),widgets.FloatSlider()])

# %%
widgets.HTML(
    value="Hello <b>World</b>",
    placeholder='Some HTML',
    description='Some HTML'
)
# Out:
# HTML(value='Hello <b>World</b>', description='Some HTML', placeholder='Some HTML')

# %% [markdown]
# # Widget Styling and Layout

# %%
import ipywidgets as widgets 
from IPython.display import display

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
w.layout.margin = 'auto'
w.layout.height = '75px'

# %%
widgets.Button(description='Ordinary Button',button_style='success')
# Out:
# Button(button_style='success', description='Ordinary Button', style=ButtonStyle())

# %%
b1 = widgets.Button(description='Custom Color')
b1.style.button_color = 'lightgreen'
b1
# Out:
# Button(description='Custom Color', style=ButtonStyle(button_color='lightgreen'))

# %%
b1.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'button_color',
#  'font_family',
#  'font_size',
#  'font_style',
#  'font_variant',
#  'font_weight',
#  'text_color',
#  'text_decoration']

# %%
b2 = widgets.Button(description='NEW')
b2.style = b1.style
b2
# Out:
# Button(description='NEW', style=ButtonStyle(button_color='lightgreen'))
