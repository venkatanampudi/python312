# %% [markdown]
# ### SENDING EMAIL WITH PYTHON
# - ```Gmail   --> smtp.gmail.com```
# - ```Yahoo   --> smtp.mail.yahoo.com```
# - ```Outlook --> smtp-mail.outlook.com```
# - ```SMTP = Simple Mail Transfer Protocol```

# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com',587)

# %%
# ehlo ==> extended hello to mail server
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [172.59.215.178]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
password = input('What is your password: ')
# Out:
# What is your password:  Hello

# %%
import getpass

# %%
password = getpass.getpass('Password Please')
# Out:
# Password Please ········

# %%
# CHECK IF LOGIN SUCCESSFUL BEFORE SENDING EMAIL...
import smtplib
import getpass

email = getpass.getpass("Email: ")
password = getpass.getpass("App Password: ")

smtp_object = smtplib.SMTP("smtp.gmail.com", 587)
smtp_object.ehlo()
smtp_object.starttls()       # very important
smtp_object.ehlo()           # run EHLO again after TLS

smtp_object.login(email, password)

print("Login successful!")

# %%
# GENERATE APP PASSWORD USING Gmail App Password URL 
email = getpass.getpass("Email: ")
password = getpass.getpass("App Password: ")
smtp_object.login(email,password)

# %%
from_address = email 
to_address = email 
subject = input("Enter the subject line: ")
message = input("Enter the body message: ")

msg = "Subject: "+subject+'\n'+message

smtp_object.sendmail(from_address,to_address,msg)
# Out:
# Enter the subject line:  This is from Python
# Enter the body message:  This email from Python
# {}

# %%
# CHECK GMAIL ACCOUNT IF YOU RECEIVE EMAIL FROM THIS PROGRAM.

# %%
smtp_object.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPServerDisconnected                    Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 smtp_object.quit()
#
# File ~\anaconda3\Lib\smtplib.py:993, in SMTP.quit(self)
#     991 def quit(self):
#     992     """Terminate the SMTP session."""
# --> 993     res = self.docmd("quit")
#     994     # A new EHLO is required after reconnecting with connect()
#     995     self.ehlo_resp = self.helo_resp = None
#
# File ~\anaconda3\Lib\smtplib.py:431, in SMTP.docmd(self, cmd, args)
#     429 def docmd(self, cmd, args=""):
#     430     """Send a command, and return its response code."""
# --> 431     self.putcmd(cmd, args)
#     432     return self.getreply()
#
# File ~\anaconda3\Lib\smtplib.py:378, in SMTP.putcmd(self, cmd, args)
#     374     s = s.replace('\n', '\\n').replace('\r', '\\r')
#     375     raise ValueError(
# ...
