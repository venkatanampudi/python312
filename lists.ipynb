# %%
import sys
print(sys.version)
# Out:
# 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# # Lists
# * Lists are __ordered__ sequences that can hold a variety of object types
# * They use [] brackets and commands to separate objects in the list [1,2,3,4,5,"Hello"]
# * Lists support indexing and slicing. Lists can be nested and also have a variety of useful methods that can be called off of them.

# %%
my_list=[1,2,3]

# %%
myl=["STRING",100,23.1]
len(myl)
# Out:
# 3

# %%
myl=['one','two','three']

# %%
myl[0]
# Out:
# 'one'

# %%
myl2=['four','five']

# %%
myl+myl2 # cancatenating lists
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
myl
# Out:
# ['one', 'two', 'three']

# %%
myl2
# Out:
# ['four', 'five']

# %%
newlist=myl+myl2

# %%
newlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlist[0]="ONE ALL CAPS"

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
newlist.append('six') # appned add the item at last

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
newlist.append(7)

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six', 7]

# %%
# pop --> is going to pop off the last item from the list and return the popped item
newlist.pop()
# Out:
# 7

# %%
popped_item=newlist.pop() # saving popped item. Every time we run this, it will pop off the last item from the list

# %%
popped_item
# Out:
# 'four'

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three']

# %% [markdown]
# ### Difference between Function and Method in Python
# * function --> is a block of code that performs a specific task. A function called independently. Ex: print(), len()
# * method --> is a function that is associated with an object. A method called using an object (instance or class). Ex: "Hello".upper()

# %%
# popping off the indexed position of the list. Just pass the index to pop() method
newlist.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
newlist
# Out:
# ['two', 'three']

# %%
newlist.pop(0)
# Out:
# 'two'

# %%
newlist
# Out:
# ['three']

# %%
new_list=['a','e','x','b','c']

# %%
new_list.sort() # this sort method wont return anything (its inplace method).if you assing to variable, it wont return anything.
my_sorted_list=new_list.sort()

# %%
my_sorted_list #here it wont return anything

# %%
type(my_sorted_list)
# Out:
# NoneType

# %%
# NoneType is none object for None. It has no value.

# %%
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list=[4,1,8,3]

# %%
num_list
# Out:
# [4, 1, 8, 3]

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
# Rever method of a list. This also inplace, means it wont return anything.
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]

# %%
# Nested list
my_nested_list=[0,1,[1,2]]

# %%
# grabbing 2 from [0,1,[1,2]]
my_nested_list[2][1]
# Out:
# 2

# %%
my_nested_list_1=[0,1,[2,3,[4,5]]]

# %%
# grab 5 from this list 
my_nested_list_1[2][2][1]
# Out:
# 5
