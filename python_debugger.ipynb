# %%
# Python debugger

# %%
import pdb #IMPORTING PYTHON DEBUGGER

# %%
x = [1,2,3]
y = 2 
z = 3 

result_one = y + z
result_two = y + x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 z = 3
#       5 result_one = y + z
# ----> 6 result_two = y + x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
# SETTING PDB TRACE
x = [1,2,3]
y = 2 
z = 3 

result_one = y + z

pdb.set_trace()   # SETTING DEBUGGER TRACE BEFORE THE ERROR LINE OF CODE

result_two = y + x
# Out:
# --Return--
# None
# > c:\users\venka\appdata\local\temp\ipykernel_21628\4186433832.py(8)<module>()
# ipdb>  x
# [1, 2, 3]
# ipdb>  result_one
# 5
# ipdb>  y
# 2
# ipdb>  x
# [1, 2, 3]
# ipdb>  y+x
# *** TypeError: unsupported operand type(s) for +: 'int' and 'list'
# ipdb>  x+y
# *** TypeError: can only concatenate list (not "int") to list
# ipdb>  y+z
# 5
