# %% [markdown]
# ### Modulo or "Mod" operator (%) --> remainder after division

# %%
7 % 4
# Out:
# 3

# %%
8 % 2
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %% [markdown]
# ### Exponential (power) operator (**)

# %%
2 ** 3
# Out:
# 8

# %%
10 ** 2
# Out:
# 100

# %%
9 ** 2
# Out:
# 81
